# %%
import pandas as pd
import numpy as np

# %%
file1 = open('times.txt', 'r')
Lines = file1.readlines()
for line in Lines:
    count += 1
    print("Line{}: {}".format(count, line.strip()))

# %%
filename = '/home/daniel/CLionProjects/HPC/gameoflife/Benchmarks/times.txt'
pd.read_csv(filename)
# Out:
#      21.11.28|10:13:41   i: 0   Program: ./gameoflife 600 1024 1024 1 1  \
# 0    21.11.28|10:13:41   i: 1   Program: ./gameoflife 600 1024 1024 1 1
# 1    21.11.28|10:13:41   i: 2   Program: ./gameoflife 600 1024 1024 1 1
# 2    21.11.28|10:13:41   i: 3   Program: ./gameoflife 600 1024 1024 1 1
# 3    21.11.28|10:13:41   i: 4   Program: ./gameoflife 600 1024 1024 1 1
# 4    21.11.28|10:13:41   i: 0    Program: ./gameoflife 600 512 1024 2 1
# ..                 ...    ...                                       ...
# 204  21.11.28|10:13:41   i: 0     Program: ./gameoflife 33 4096 512 1 8
# 205  21.11.28|10:13:41   i: 1     Program: ./gameoflife 33 4096 512 1 8
# 206  21.11.28|10:13:41   i: 2     Program: ./gameoflife 33 4096 512 1 8
# 207  21.11.28|10:13:41   i: 3     Program: ./gameoflife 33 4096 512 1 8
# 208  21.11.28|10:13:41   i: 4     Program: ./gameoflife 33 4096 512 1 8
#
#       TotalTime: 0:56.33    CPU: 99%    Memory:18020k
# 0     TotalTime: 0:58.14    CPU: 99%    Memory:18004k
# 1     TotalTime: 1:01.12    CPU: 99%    Memory:18004k
# 2     TotalTime: 1:03.38    CPU: 99%    Memory:17988k
# 3     TotalTime: 1:03.15    CPU: 99%    Memory:17960k
# 4     TotalTime: 0:35.95   CPU: 199%    Memory:18056k
# ..                   ...         ...              ...
# 204   TotalTime: 0:15.08   CPU: 557%   Memory:263756k
# 205   TotalTime: 0:14.68   CPU: 573%   Memory:263720k
# 206   TotalTime: 0:14.67   CPU: 574%   Memory:263720k
# 207   TotalTime: 0:14.78   CPU: 572%   Memory:263720k
# 208   TotalTime: 0:14.69   CPU: 575%   Memory:263812k
#
# [209 rows x 6 columns]

# %%
for line in Lines:
    count += 1
    print("Line{}: {}".format(count, line.strip()))

# %%
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3
